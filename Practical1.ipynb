# %% [markdown]
# ### Graph of number of elements vs time for linear search

# %%
import matplotlib.pyplot as plt

# %%
n_number=[100,500,1000,5000,10000]
time=[0,0,0.001000,0.003000,0.010000]
plt.plot(n_number,time)
plt.xlabel("Number of elements in array")
plt.ylabel("Time in seconds")
plt.title("Analysis for linear search")
plt.legend()
plt.grid(True)
plt.show
# Out:
# C:\Users\Dhruv\AppData\Local\Temp\ipykernel_11192\1249477780.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Graph of number of elements vs time for binary search

# %%
n_number=[100,500,1000,5000,10000,100000,1000000]
time=[0,0,0,100,300,300,500]
plt.plot(n_number,time)
plt.xlabel("Number of elements in array")
plt.ylabel("Time in nano-seconds")
plt.title("Analysis for linear search")
plt.legend()
plt.grid(True)
plt.show
# Out:
# C:\Users\Dhruv\AppData\Local\Temp\ipykernel_11192\2577861307.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>
